# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
#import project_code as pc
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
#funkcja import pliku
def f_file_import(name:str):
    return pd.read_csv(name)

# %%
#Zaimportowanie pliku z pc
df_clean = f_file_import('df_clean.csv')

# %%
#definicja development
#funkcja agregująca dane do nowego DF
def aggregate_fun(df, agg_list:list, measure:str):
    agg_df = df.groupby(agg_list)[measure].agg(['count',sum,'mean', 'median']).reset_index()
    agg_df.rename(columns= {'count':'count_x', 'sum':'sum_x', 'mean':'mean_x', 'median':'median_x'}, inplace=True)
    return agg_df
    #['country','main_category'] 'usd_pledged_real'

# %%
#funkcja bar plot z procentami
def barplot_pct(df, lista_2_elementy:list , kolor='pastel'):
    #agregujemy po 2 zmiennych, otrzymujemy count, sum, mean, median
    df_new = aggregate_fun(df, lista_2_elementy, 'ID' )
        #['country', 'main_category']
    
    #zmieniamy nazwę w nowo utworzonym DF, bo wysypuje się na nazwach typu count
    df_new.rename(columns= {'count_x':'count_y', 'sum_x':'sum_y', 'mean_x':'mean_y', 'median_x':'median_y'}, inplace=True)

    #agregujemy drugiego DF po 1 zmiennej - będziemy brać z tego sumę
    df_new_1 = aggregate_fun(df_new, lista_2_elementy[1], 'count_y')
        #['main_category']

    #zmieniamy nazwę drugiego DF, bo wysypuje się na nazwach typu count
    #df_new_1.rename(columns= {'count':'count_x', 'sum':'sum_x', 'mean':'mean_x', 'median':'median_x'}, inplace=True)

    #merge'ujemy powyższe DFy, z pierwszego bierzemy count_y, z drugiego sum_x,
    # merge jako inner join, łączenie po XXXXXX
    df_new_2 = pd.merge(df_new[[lista_2_elementy[0], lista_2_elementy[1], 'count_y']],
    df_new_1[[lista_2_elementy[1],'sum_x']], how='inner', on=lista_2_elementy[1])
        #'country','main_category'
        #'main_category' x2

    #Tworzymy nową kolumnę procent
    df_new_2['pct'] = df_new_2['count_y']/df_new_2['sum_x'] * 100

    #Odwołanie do funkcji tworzącej wykres
    bar_plot_2_var(df_new_2, lista_2_elementy[1], lista_2_elementy[0],'pct', kolor,2,8);
        #'main_category' 'country'
    

#agg_country_main_category.rename(columns= {'count':'count_y', 'sum':'sum_y', 'mean':'mean_y', 'median':'meadian_y'}, inplace=True)
#agg_country_main_category.head()

# %%
#definicja development
#funkcja wykres słupkowy - liczebność - dwie zmienne - col x
def bar_plot_2_var(df, var_col:str, var_x:str, var_y:str, palette_list:list,column_wrap:int =3, height_value:float = 4):
    g = sns.catplot(data = df, col = var_col , x = var_x, y=var_y, kind = 'bar', height = height_value, col_wrap=column_wrap, palette = palette_list,sharex = False)
    g.set_titles('{col_name}');

# %%
#definicja development
#funkcja wykres słupkowy - liczebność - dwie zmienne - col x
def count_plot_col(df, var1:str, var2:str,column_wrap:int =3, height_value:float = 4):
    g = sns.catplot(data = df, col = var1 , x = var2,  kind = 'count', height = height_value, col_wrap=column_wrap, sharex=False)
    g.set_titles('{col_name}');
    #'country' 'main_category' 'count'
    #y = measure ,

# %%
#funkcja 3 zmienne - po aggregujących  
def bar_plot_3_var(df, var_col:str, var_x:str, var_y:str, hue_var:str,zmienna_ilosciowa:str, palette_list:list, column_wrap:int =3, height_value:float = 4):
    df_new = aggregate_fun(df, [var_x, var_col, hue_var], zmienna_ilosciowa )
    g = sns.catplot(data = df_new, col = var_col , x = var_x, y = var_y, hue = hue_var, kind = 'bar', height = height_value, col_wrap = column_wrap, palette = palette_list, sharex = False)
    g.set_titles('{col_name}');

# %%
#funkcja 3 zmienne - bez agregacji   
def bar_plot_3_var_no_agg(df, var_col:str, var_x:str, var_y:str, hue_var:str, palette_list:list, column_wrap:int =3, height_value:float = 4):
    g = sns.catplot(data = df, col = var_col , x = var_x, y = var_y, hue = hue_var, kind = 'bar', height = height_value, col_wrap = column_wrap, palette = palette_list, sharex = False)
    g.set_titles('{col_name}');

# %%
#funkcja wykres słupkowy - liczebność - jedna zmienna
def bar_plot_1_var(name, group_var:str, size:tuple = (10,6), colors = ['r', 'g'], alph=1):
    name.groupby(group_var)[group_var].count().sort_values(ascending = False).plot(kind = 'bar', figsize = size, color=colors,alpha=alph);

# %%
#funkcja wykres słupkowy - liczebność - jedna zmienna - dla dat
def bar_plot_1_var_date(name, group_var:str, size:tuple = (10,6)):
    name.groupby(group_var)[group_var].count().plot(kind = 'bar', figsize = size);

# %%
#funkcja wykres słupkowy - średnia - jedna zmienna + zmienna grupowana
# var1 - zmienna grupująca, var2 - zmienna grupowana
def bar_plot_1_var_mean(df, group_var:str, groupped_var:str):
    df.groupby(group_var)[groupped_var].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,8));

# %%
#definicja development
#funkcja sortująca
def sorting_values(df_agg, value_by:str = 'mean', sorting_var:bool = False):
    return df_agg.sort_values(by =value_by, ascending= sorting_var).reset_index()

# %%
#definicja development
#funkcja wykres słupkowy - średnia - dwie zmienne
# var1 - zmienna grupująca, var2 - zmienna grupowana
def f_barplot_2_var_mean(name, var1:str, var2:str, size:tuple = (10,6)):
    name.groupby(var1)[var2].mean().sort_values(ascending=False).plot(kind='bar', figsize = size);

# %%
#funkcja filtrująca - 
#df_zadana_kwota = df_clean.query('usd_goal_real < 10000')
def filter_lower_equal(df, x, var_bar_plot:list, color='pastel'):
    
    df_zadana_kwota = df[df.usd_goal_real <= x]
    g = barplot_pct(df_zadana_kwota, var_bar_plot, color)
    #var_bar_plot = ['state','main_category']

# %%
#funkcja tworząca liste unikalnych wartości do widgetów
def unique_value_list(df, col_var:str):
    return list(df[col_var].unique())

# %%
#funkcja tworząca liste unikalnych wartości do widgetów sortująca 
def unique_value_list_sorted(df, col_var:str):
    return sorted(list(df[col_var].unique()))

# %%
#funkcja definicja widgetu 
def widget_def(lista:list, descr:str ):
    return widgets.SelectMultiple(
    options=lista,
    value=[lista[0]],
    rows=10,
    description=descr,
    disabled=False)

# %%
def widget_layout(widget1, widget2):
    layout = widgets.Layout(display='flex',
         justify_content='space-between',
         align_items='center',                
         flex_flow='row',
         border='solid green',
         width='70%',
         style= {'description_width': 'initial'} )
    return widgets.Box(children=[widget1, widget2], layout=layout)

# %%
#funkcja bar plot z procentami
def barplot_pct_3_var(df, lista_3_elementy:list):
    #agregujemy po 2 zmiennych, otrzymujemy count, sum, mean, median
    df_new = aggregate_fun(df, lista_3_elementy, 'ID' )
        #['country', 'main_category']
    
    #zmieniamy nazwę w nowo utworzonym DF, bo wysypuje się na nazwach typu count
    df_new.rename(columns= {'count_x':'count_y', 'sum_x':'sum_y', 'mean_x':'mean_y', 'median_x':'median_y'}, inplace=True)

    #agregujemy drugiego DF po 2 elementach - będziemy brać z tego sumę
    df_new_1 = aggregate_fun(df_new, lista_3_elementy[0:2], 'count_y')
        #['main_category']

    #zmieniamy nazwę drugiego DF, bo wysypuje się na nazwach typu count
    #df_new_1.rename(columns= {'count':'count_x', 'sum':'sum_x', 'mean':'mean_x', 'median':'median_x'}, inplace=True)

    #merge'ujemy powyższe DFy, z pierwszego bierzemy count_y, z drugiego sum_x,
    # merge jako inner join, łączenie po XXXXXX
    df_new_2 = pd.merge(df_new[[lista_3_elementy[0], lista_3_elementy[1],lista_3_elementy[2], 'count_y']],
    df_new_1[[lista_3_elementy[0],lista_3_elementy[1],'sum_x']], how='inner', on=lista_3_elementy[0:2])
        #'country','main_category'
        #'main_category' x2

    #Tworzymy nową kolumnę procent
    df_new_2['pct'] = df_new_2['count_y']/df_new_2['sum_x'] * 100

    #Odwołanie do funkcji tworzącej wykres
    bar_plot_3_var_no_agg(df_new_2,'main_category', 'duration', 'pct', 'state', ['r', 'g'], 1, 15.0)
        #'main_category' 'country'
    

#agg_country_main_category.rename(columns= {'count':'count_y', 'sum':'sum_y', 'mean':'mean_y', 'median':'meadian_y'}, inplace=True)
#agg_country_main_category.head()

# %%
#tworzymy listy
list_main_cat = unique_value_list(df_clean, 'main_category')
list_country = unique_value_list(df_clean, 'country')
list_launched_year = unique_value_list_sorted(df_clean, 'launched_year')

# %%
# widgety
widget_main_cat = widget_def(list_main_cat, 'Kategoria')
widget_country = widget_def(list_country, 'Kraj' )
widget_launched_year = widget_def(list_launched_year, 'Rok uruchomienia zbiórki' )
widget_days = widgets.IntRangeSlider(
    value=[1, 60],
    min=1,
    max=60,
    step=1,
    description='Czas trwania zbiórki:',
    style={'description_width':'initial'},
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
widget_value = widgets.IntText(description='Cel zbiórki <=')

# %% [markdown]
# ## Podsumowania

# %% [markdown]
# ##### Rozkład na rok założenia zbiórki

# %%
year_count = bar_plot_1_var_date(df_clean, 'launched_year')

# %% [markdown]
# ##### Rozkład na miesiące

# %%
year_count = bar_plot_1_var_date(df_clean, 'launched_month')

# %% [markdown]
# ##### Rozkład liczby zbiórek w krajach

# %%
country_count = bar_plot_1_var(df_clean, 'country',colors='b',alph=0.4)

# %% [markdown]
# ##### Popularność kategorii

# %%
main_category_count = bar_plot_1_var(df_clean, 'main_category',colors = 'b',alph=0.4)

# %% [markdown]
# ##### Rozkład sukcesów i porażek

# %%
state_count = bar_plot_1_var(df_clean, 'state',alph=0.6)

# %% [markdown]
# ##### Średni hajs zebrany na kategoriach

# %%
main_category_usd_pledged_real_mean = bar_plot_1_var_mean(df_clean, 'main_category', 'usd_pledged_real')

# %% [markdown]
# ##### Zbiórki odnoszące sukces poniżej danej kwoty

# %%
widget_maincat_value = widget_layout(widget_main_cat, widget_value)
widget_maincat_value
# Out:
# Box(children=(SelectMultiple(description='Kategoria', index=(0,), options=('Publishing', 'Film & Video', 'Musi…

# %%
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    value_max = widget_value.value
    #tworzę listę wybranych lat
    list_wdg_main_category = list(widget_main_cat.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['main_category'].isin(list_wdg_main_category))]
    #Tworzę wykres na podstawie nowego DF    
    return filter_lower_equal(df_new, value_max, ['state','main_category'], ['r','b'])

display(refresh_button, output)
refresh_button.on_click(refresh)
# Out:
# Button(description='Odśwież', style=ButtonStyle())
# Output()

# %% [markdown]
# # W którym kraju jaka kategoria jest najbardziej popularna i dochodowa

# %%
#potrzebne zmienne:
"""
country
main_category
zagregowana tabela z liczebnościami, procentami, średnią i medianą dla usd_goal_real oraz usd_pledged_real
"""
#potrzebne funkcje
"""
    #popularność:
    + wykres country od main_category - liczebności i procenty
    + wykres country od state - liczebność i procenty
    #dochodowość:
    + agregująca
    + wykres country od main_category i state - średnia i mediana dla usd_goal_real oraz usd_pledged_real
"""
# Out:
# '\n    #popularność:\n    + wykres country od main_category - liczebności i procenty\n    + wykres country od state - liczebność i procenty\n    #dochodowość:\n    + agregująca\n    + wykres country od main_category i state - średnia i mediana dla usd_goal_real oraz usd_pledged_real\n'

# %%
df_new = aggregate_fun(df_clean, ['country', 'main_category'], 'ID' )

# %%
df_new
# Out:
#     country main_category  count_x           sum_x        mean_x      median_x
# 0        AT           Art       29     27392404419  9.445657e+08  8.360882e+08
# 1        AT        Comics        6      7621340265  1.270223e+09  1.145371e+09
# 2        AT        Crafts        9     12614969179  1.401663e+09  1.564176e+09
# 3        AT         Dance        3      1638547601  5.461825e+08  2.837286e+08
# 4        AT        Design       64     68409141307  1.068893e+09  1.050792e+09
# ..      ...           ...      ...             ...           ...           ...
# 313      US         Music    40225  43241728098185  1.074996e+09  1.070683e+09
# 314      US   Photography     7229   7703722729831  1.065669e+09  1.054548e+09
# 315      US    Publishing    28677  30907576422499  1.077783e+09  1.082751e+09
# 316      US    Technology    18058  19402543972947  1.074457e+09  1.072457e+09
# 317      US       Theater     8194   8784293456622  1.072040e+09  1.070385e+09
#
# [318 rows x 6 columns]

# %%
country_main_category_barplot_pct = barplot_pct(df_clean,['country', 'main_category'])
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
widget_maincat_country = widget_layout(widget_main_cat, widget_country)
widget_maincat_country
# Out:
# Box(children=(SelectMultiple(description='Kategoria', index=(0,), options=('Publishing', 'Film & Video', 'Musi…

# %%
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_main_cat.value)
    #tworzę listę wybranych lat
    list_wdg_country = list(widget_country.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['main_category'].isin(list_wdg_main_category) ) & ( df_clean['country'].isin(list_wdg_country) )]
    #Tworzę wykres na podstawie nowego DF
    return barplot_pct(df_new,['country', 'main_category'])

display(refresh_button, output)
refresh_button.on_click(refresh)
# Out:
# Button(description='Odśwież', style=ButtonStyle())
# Output()

# %%
country_state_barplot_pct = barplot_pct(df_clean,['country', 'state'])
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
country_state_barplot_pct = barplot_pct(df_clean,['state', 'country'])
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
widget_country
# Out:
# SelectMultiple(description='Kraj', index=(0,), options=('GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', …

# %%
# liczba zbiórek w danym kraju
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_country = list(widget_country.value)
    #tworzę listę wybranych lat
    #list_wdg_launched_year = list(wdg_year_main_category_count__launched_year.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['country'].isin(list_wdg_country) )] #& ( df_clean['launched_year'].isin(list_wdg_launched_year) )]
    #Tworzę wykres na podstawie nowego DF
    barplot_pct(df_new,['country', 'state'])
    barplot_pct(df_new,['state', 'country'], ['#ed1515','g'])

display(refresh_button, output)
refresh_button.on_click(refresh)
# Out:
# Button(description='Odśwież', style=ButtonStyle())
# Output()

# %%
#Tak wyglądają wszystkie wykresy
country_main_category = count_plot_col(df_clean, 'main_category', 'country', 2,8)
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
widget_maincat_country = widget_layout(widget_main_cat, widget_country)
widget_maincat_country
# Out:
# Box(children=(SelectMultiple(description='Kategoria', index=(0,), options=('Publishing', 'Film & Video', 'Musi…

# %%
#Do dorobienia button

refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    print(type(b))
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_main_cat.value)
    #tworzę listę wybranych lat
    list_wdg_country = list(widget_country.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['main_category'].isin(list_wdg_main_category) ) & ( df_clean['country'].isin(list_wdg_country) )]
    #Tworzę wykres na podstawie nowego DF
    return count_plot_col(df_new, 'main_category', 'country', 2,8)

display(refresh_button, output)
refresh_button.on_click(refresh)
# Out:
# Button(description='Odśwież', style=ButtonStyle())
# Output()

# %%
"""
#agregujemy country od main_category i state
agg_country_main_cat_state = aggregate_fun(df_clean, ['country','main_category','state'], 'ID' )
#zapis zamiast notacji wykładniczej:
pd.set_option('display.float_format', '{:.2f}'.format)
agg_country_main_cat_state
"""
# Out:
# "\n#agregujemy country od main_category i state\nagg_country_main_cat_state = aggregate_fun(df_clean, ['country','main_category','state'], 'ID' )\n#zapis zamiast notacji wykładniczej:\npd.set_option('display.float_format', '{:.2f}'.format)\nagg_country_main_cat_state\n"

# %%
bar_plot3 = bar_plot_3_var(df_clean, var_col = 'main_category', var_x = 'country', var_y = 'median_x', hue_var = 'state',zmienna_ilosciowa = 'usd_goal_real', palette_list = ['r', 'g'],column_wrap =2, height_value = 6)

# %%
widget_maincat_country = widget_layout(widget_main_cat, widget_country)
widget_maincat_country
# Out:
# Box(children=(SelectMultiple(description='Kategoria', index=(0,), options=('Publishing', 'Film & Video', 'Musi…

# %%
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_main_cat.value)
    #tworzę listę wybranych lat
    list_wdg_country = list(widget_country.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['main_category'].isin(list_wdg_main_category) ) & ( df_clean['country'].isin(list_wdg_country) )]
    #Tworzę wykres na podstawie nowego DF
    return bar_plot_3_var(df_new, var_col = 'main_category', var_x = 'country', var_y = 'median_x', hue_var = 'state',zmienna_ilosciowa = 'usd_goal_real', palette_list = ['r', 'g'],column_wrap =2, height_value = 6)

display(refresh_button, output)
refresh_button.on_click(refresh)
# Out:
# Button(description='Odśwież', style=ButtonStyle())
# Output()

# %% [markdown]
# # wzrost popularności rok po roku/miesiąc po miesiącu

# %%
#potrzebne zmienne:
"""
rok i miesiąc launched
(kwartał launched)
zagregowana tabela z liczebnościami, YoY
"""
#potrzebne funkcje
"""
    + agregująca
    + wykres rok/miesiąc (kwartał) liczebności
    + wykres rok/miesiąc w kontekście innej zmiennej, przykładowo main_category
    - wykres zmian procentowych rok do roku/miesiąc do miesiąca(/kwartał do kwartału)
"""
# Out:
# '\n    + agregująca\n    + wykres rok/miesiąc (kwartał) liczebności\n    + wykres rok/miesiąc w kontekście innej zmiennej, przykładowo main_category\n    - wykres zmian procentowych rok do roku/miesiąc do miesiąca(/kwartał do kwartału)\n'

# %%
#Widget do poniższych wykresów
widget_layout(widget_main_cat, widget_launched_year)
# Out:
# Box(children=(SelectMultiple(description='Kategoria', index=(0,), options=('Publishing', 'Film & Video', 'Musi…

# %%
#Tu powinien być button

# %%
#Tak wyglądają wszystkie wykresy
year_main_category_count = count_plot_col(df_clean, 'main_category', 'launched_year')
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %% [markdown]
# # ile średnio wpłacała jednostka per kategoria/podkategoria

# %%
#potrzebne zmienne:
"""
main_category
średnia usd_pledged_real
"""
#potrzebne funkcje
"""
 + wykres średniej kwoty na kategorie
"""
# Out:
# '\n + wykres średniej kwoty na kategorie\n'

# %% [markdown]
# ***

# %% [markdown]
# ### Kraje

# %%
#widget do poniższego wykresu
widget_country
# Out:
# SelectMultiple(description='Kraj', index=(0,), options=('GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', …

# %%
# liczba zbiórek w danym kraju
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_country.value)
    #tworzę listę wybranych lat
    #list_wdg_launched_year = list(wdg_year_main_category_count__launched_year.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['country'].isin(list_wdg_main_category) )] #& ( df_clean['launched_year'].isin(list_wdg_launched_year) )]
    #Tworzę wykres na podstawie nowego DF
    return f_barplot_1_var(df_new, 'country')

display(refresh_button, output)
refresh_button.on_click(refresh)
# Out:
# Button(description='Odśwież', style=ButtonStyle())
# Output()

# %% [markdown]
# ### Kategoria Główna

# %% [markdown]
# ### Statusy

# %%
country_state_usd_goal_real_df = aggregate_fun(df_clean, ['country', 'state'], 'usd_goal_real')

# %%
country_state_usd_goal_real_df
# Out:
#    country       state  count_x         sum_x         mean_x   median_x
# 0       AT      failed      378  1.855354e+07   49083.428757  11735.420
# 1       AT  successful      107  1.879291e+06   17563.468785   7887.590
# 2       AU      failed     4606  3.513705e+08   76285.384952   7443.250
# 3       AU  successful     2010  1.602063e+07    7970.463592   3454.630
# 4       BE      failed      371  1.627575e+07   43869.946173   8708.810
# 5       BE  successful      152  2.285224e+06   15034.365789   3531.270
# 6       CA      failed     8236  5.229057e+08   63490.250461   7382.375
# 7       CA  successful     4134  3.146861e+07    7612.146251   3488.255
# 8       CH      failed      465  1.960094e+08  421525.553312  16400.540
# 9       CH  successful      187  3.947156e+06   21107.786578  10248.630
# 10      DE      failed     2499  2.536111e+08  101485.045966  11005.940
# 11      DE  successful      937  1.275701e+07   13614.734194   5175.240
# 12      DK      failed      566  1.654441e+07   29230.412138   7266.885
# 13      DK  successful      360  3.307378e+06    9187.161944   2835.905
# 14      ES      failed     1381  9.538343e+07   69068.376343   8907.790
# 15      ES  successful      492  4.801053e+06    9758.237134   3943.810
# 16      FR      failed     1612  2.119308e+08  131470.710974  11013.940
# 17      FR  successful      908  1.199909e+07   13214.852555   5838.050
# 18      GB      failed    17387  1.058792e+09   60895.593468   6730.270
# 19      GB  successful    12067  9.860734e+07    8171.653679   2516.010
# 20      HK      failed      261  8.759696e+06   33562.054291  10313.130
# 21      HK  successful      216  2.784405e+06   12890.763194   6418.530
# 22      IE      failed      476  2.782211e+07   58449.820819   7336.025
# 23      IE  successful      207  2.248125e+06   10860.509275   4055.810
# 24      IT      failed     1930  1.912716e+08   99104.481746  11745.585
# 25      IT  successful      439  4.402758e+06   10029.062620   3946.530
# 26      JP      failed       16  2.656203e+05   16601.266250   8901.565
# 27      JP  successful        7  3.136848e+04    4481.211429   2632.960
# 28      LU      failed       38  1.648116e+06   43371.481316  14712.520
# 29      LU  successful       19  2.843460e+05   14965.576316   2435.410
# 30      MX      failed     1015  1.872038e+07   18443.720414   3033.710
# 31      MX  successful      396  1.419329e+06    3584.164470   2416.390
# 32      NL      failed     1794  1.613765e+08   89953.460708  10963.955
# 33      NL  successful      617  7.912611e+06   12824.328428   5642.000
# 34      NO      failed      420  2.466873e+07   58735.074214   6229.340
# 35      NO  successful      162  1.093030e+06    6747.101667   3365.100
# 36      NZ      failed      826  2.742527e+07   33202.509189   6825.955
# 37      NZ  successful      448  3.240879e+06    7234.105000   3068.080
# 38      SE      failed     1000  5.404330e+07   54043.301830   6045.950
# 39      SE  successful      509  4.468529e+06    8779.036189   3649.460
# 40      SG      failed      276  5.080695e+06   18408.315725   6585.700
# 41      SG  successful      178  1.677915e+06    9426.487753   3731.370
# 42      US      failed   152061  9.224665e+09   60664.242108   7500.000
# 43      US  successful   109299  1.059727e+09    9695.670955   4000.000

# %%
#to ląduje pod wykresem country, state, liczebność

#średnia kwota celu w poszczególnych krajach w podziale na udane i nieudane projekty
bar_plot_2_var(country_state_usd_goal_real_df, 'state', 'country', 'mean_x', 'pastel',8)
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
widget_country
# Out:
# SelectMultiple(description='Kraj', index=(0,), options=('GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', …

# %%
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_country.value)
    #tworzę listę wybranych lat
    #list_wdg_launched_year = list(wdg_year_main_category_count__launched_year.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['country'].isin(list_wdg_main_category) )] #& ( df_clean['launched_year'].isin(list_wdg_launched_year) )]
    #Tworzę wykres na podstawie nowego DF
    df_new1 = aggregate_fun(df_new, ['country', 'state'], 'usd_goal_real')
    return bar_plot_2_var(df_new1, 'country', 'state', 'mean_x', ['r', 'g'],2,8)

display(refresh_button, output)
refresh_button.on_click(refresh)

# %%
bar_plot_2_var(country_state_usd_goal_real_df, 'country', 'state', 'mean_x', 'pastel',8)
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %%
#widget do powyższego
widget_country
# Out:
# SelectMultiple(description='Kraj', index=(0,), options=('GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', …

# %%
#Tu powinien być button do powyższego

# %%
country_state_usd_pledged_real_df = aggregate_fun(df_clean, ['country', 'state'], 'usd_pledged_real')

# %%
#średnia uzbierana kwota w poszczególnych krajach w podziale na udane i nieudane projekty
bar_plot_2_var(country_state_usd_pledged_real_df, 'country', 'state', 'mean_x', ['r','g'])
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %% [markdown]
# ## czy małe projekty (kwotowo) łatwiej odnoszą sukces

# %%
#potrzebne zmienne:
"""
'state'
'usd_goal_real'
'main_category'

"""
#potrzebne funkcje
"""
+ użytkownik podaje kwotę i mu wyskakuję skuteczność/ile było success i fail zbiórek 
    
"""

# %%
#Tu trzeba dorobić widget (wpisanie kwoty z palca)
da = filter_lower_equal(df_clean, 15000, ['state','main_category'])
# Out:
# C:\Users\jozab\anaconda3\lib\site-packages\seaborn\categorical.py:3806: UserWarning: Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.
#   warnings.warn(msg.format("sharex", "x"), UserWarning)

# %% [markdown]
# # jaki był czas zbiórki dla każdej kategorii - czy uzbierano na cel

# %%
#potrzebne zmienne:
"""
'state'
'main_category'
'duration'


"""
#potrzebne funkcje
"""
    + użytkownik podaje liczbę dni i dostaje wykres % ile było failed i succsessful
    
"""

# %%
df_dur = df_clean[df_clean['duration']<=60]
df_dur

# %%
agg_cat_dur_state = aggregate_fun(df_dur, ['main_category','duration','state'], 'ID')
agg_cat_dur_state

# %%
duration_cat_state = bar_plot_2_var(agg_cat_dur_state, 'main_category', 'duration', 'count_x', 'pastel',column_wrap=1, height_value=15)

# %%
bar_plot_3_var(df_clean, 'main_category', 'duration', 'count_x', 'state', 'ID', 'pastel', 1, 15)

# %%
#zmieniamy na 60 dni bo w 2011 zmienili czas z 90 dni na 60 dni
#df_clean.duration = df_clean['duration'].str.replace('days', ' ').astype('int')

# %%
widget_maincat_days = widget_layout(widget_main_cat, widget_days)
widget_maincat_days

# %%
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_main_cat.value)
    #tworzę listę wybranych lat
    days_tuple = list(widget_days.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['main_category'].isin(list_wdg_main_category)) & (df_clean['duration'] >= days_tuple[0]) & (df_clean['duration'] <= days_tuple[1])]
    #Tworzę wykres na podstawie nowego DF
    return bar_plot_3_var(df_new, 'main_category', 'duration', 'count_x', 'state', 'ID', ['r','g'], 1, 15)

display(refresh_button, output)
refresh_button.on_click(refresh)

# %%
 'main_category', 'duration', 'count_x', 'state', 'ID',
barplot_pct(df_clean, lista_2_elementy:list , kolor='pastel')

# %%
#funkcja bar plot z procentami
def barplot_pct_3_var(df, lista_3_elementy:list):
    #agregujemy po 2 zmiennych, otrzymujemy count, sum, mean, median
    df_new = aggregate_fun(df, lista_3_elementy, 'ID' )
        #['country', 'main_category']
    
    #zmieniamy nazwę w nowo utworzonym DF, bo wysypuje się na nazwach typu count
    df_new.rename(columns= {'count_x':'count_y', 'sum_x':'sum_y', 'mean_x':'mean_y', 'median_x':'median_y'}, inplace=True)

    #agregujemy drugiego DF po 2 elementach - będziemy brać z tego sumę
    df_new_1 = aggregate_fun(df_new, lista_3_elementy[0:2], 'count_y')
        #['main_category']

    #zmieniamy nazwę drugiego DF, bo wysypuje się na nazwach typu count
    #df_new_1.rename(columns= {'count':'count_x', 'sum':'sum_x', 'mean':'mean_x', 'median':'median_x'}, inplace=True)

    #merge'ujemy powyższe DFy, z pierwszego bierzemy count_y, z drugiego sum_x,
    # merge jako inner join, łączenie po XXXXXX
    df_new_2 = pd.merge(df_new[[lista_3_elementy[0], lista_3_elementy[1],lista_3_elementy[2], 'count_y']],
    df_new_1[[lista_3_elementy[0],lista_3_elementy[1],'sum_x']], how='inner', on=lista_3_elementy[0:2])
        #'country','main_category'
        #'main_category' x2

    #Tworzymy nową kolumnę procent
    df_new_2['pct'] = df_new_2['count_y']/df_new_2['sum_x'] * 100

    #Odwołanie do funkcji tworzącej wykres
    bar_plot_3_var_no_agg(df_new_2,'main_category', 'duration', 'pct', 'state', ['r', 'g'], 1, 15.0)
        #'main_category' 'country'
    

#agg_country_main_category.rename(columns= {'count':'count_y', 'sum':'sum_y', 'mean':'mean_y', 'median':'meadian_y'}, inplace=True)
#agg_country_main_category.head()

# %%
plot_pct_duration_state = barplot_pct_3_var(df_clean, ['main_category','duration','state'])

# %%
widget_maincat_days = widget_layout(widget_main_cat, widget_days)
widget_maincat_days

# %%
refresh_button = widgets.Button(description="Odśwież")
output = widgets.Output()


def refresh(b):
    clear_output()
    display(refresh_button, output)
    #tworzę listę wybranych kategorii
    list_wdg_main_category = list(widget_main_cat.value)
    #tworzę listę wybranych lat
    days_tuple = list(widget_days.value)
    #Filtruję DF wg wybranych kategorii
    df_new = df_clean[( df_clean['main_category'].isin(list_wdg_main_category)) & (df_clean['duration'] >= days_tuple[0]) & (df_clean['duration'] <= days_tuple[1])]
    #Tworzę wykres na podstawie nowego DF
    return barplot_pct_3_var(df_new, ['main_category','duration','state'])

display(refresh_button, output)
refresh_button.on_click(refresh)
